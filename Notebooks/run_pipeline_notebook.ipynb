# %% [markdown]
# # Master Pipeline
# اجرای کل فرآیند بازتولید داده‌ها و تحلیل.

# %%
# اجرای توالی عملیات
print('--- Step 1: Reconstructing Data ---')
# %run 01_reconstruct_rater_data.ipynb

print('\n--- Step 2: Running Analysis ---')
# %run 02_statistical_analysis.ipynb

print('\n--- Step 3: Generating Visuals ---')
# %run 03_generate_figures.ipynb
