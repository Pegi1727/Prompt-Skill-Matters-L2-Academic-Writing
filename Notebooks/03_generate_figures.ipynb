# %% [markdown]
# # 3. Generate Figures
# تولید خروجی‌های بصری برای مقاله.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

df = pd.read_csv('raw_rater_scoring.csv')
plt.figure(figsize=(8, 6))

# Scatter plot
sns.regplot(data=df, x='Raw_PSI_Mean', y='Avg_PSI_Target')
plt.title('PSI Calibration: Raw vs Target')
plt.savefig('psi_quality_scatter_new.png', dpi=300)
plt.show()
